# %% [markdown]
# # Assignment.08 - Program 01

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Tasks

# %%
# 1 Read the data from the CSV file into a DataFrame and display the data to get a count of the number of rows.
data = pd.read_csv("ramen-ratings.csv")
data
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
# 2 Rename the Stars column to Rating.
data = data.rename(columns={'Stars': 'Rating'})

# %%
# 3 Convert the Style column to the category type.
data['Style'] = data['Style'].astype(dtype='category')
data.dtypes
# Out:
# Review #       int64
# Brand         object
# Variety       object
# Style       category
# Country       object
# Rating        object
# Top Ten       object
# dtype: object

# %%
# 4 Drop the country column
data = data.drop('Country', axis=1)

# %%
# 5 Check that the changes were applied to the DataFrame
data.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Rating Top Ten
# 0                          T's Restaurant Tantanmen    Cup   3.75     NaN
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack      1     NaN
# 2                      Cup Noodles Chicken Vegetable   Cup   2.25     NaN
# 3                      GGE Ramen Snack Tomato Flavor  Pack   2.75     NaN
# 4                                    Singapore Curry  Pack   3.75     NaN

# %%
# 6 Rename the Brand column to Company and the Variety column to Product.
data = data.rename(columns={'Brand': 'Company'})
data = data.rename(columns={'Variety': 'Product'})

# %%
# 7 Use the duplicated() method to display all rows with duplicate Company/Product combinations
data[data.duplicated(['Company', 'Product'], keep=False)]
# Out:
#       Review #          Company                          Product Style Rating  \
# 2         2578           Nissin    Cup Noodles Chicken Vegetable   Cup   2.25
# 24        2556   Ching's Secret       Hot Garlic Instant Noodles  Pack   4.25
# 47        2533         Nongshim                Shin Ramyun Black  Pack      5
# 70        2510          MyKuali  Penang Red Tom Yum Goong Noodle  Pack      5
# 76        2504         Nongshim                      Shin Ramyun  Pack      3
# ...        ...              ...                              ...   ...    ...
# 2548        32             Koka           Mi Hai Cua Crab Flavor  Pack    3.5
# 2555        25           Nissin         Demae Ramen Spicy Flavor  Pack      3
# 2559        21         Nongshim        Champong Oriental Noodles  Pack      4
# 2561        19         Nongshim                      Shin Ramyun  Pack      4
# 2568        12  Sapporo Ichiban                    Shrimp Flavor  Pack    2.5
#
#      Top Ten
# 2        NaN
# ...

# %%
# 8 Drop all rows with duplicate Company/Product combinations except for the first row in each set. 
# Then, display the data to get a count of the number of rows, and compare that with the original number of rows to see how many were dropped.
data = data.drop_duplicates(['Company', 'Product'], keep='first')

#2580 rows original - 2520 rows after drop = 60 rows dropped

# %%
# 9 Drop any rows that have missing values.
data = data.dropna()

# %%
# 10 Check again to make sure that all of your changes were applied.
data
# Out:
#       Review #           Company  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1109      1471              Mama
# 1114      1466              Mama
# 1250      1330   Sapporo Ichiban
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1670       910             Paldo
# 1846       734           Indomie
# 1865       715           Indomie
# 1972       608              Koka
# 2146       434         Mi Sedaap
# ...
