# %% [markdown]
# # Assignment.08 - Program 02

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Tasks

# %%
# 1 Read the data from the CSV file into a DataFrame and display the data to get a count of the number of rows.
data = pd.read_csv("ramen-ratings.csv")

#Convert Stars to numeric
data['Stars'] = data['Stars'].replace('Unrated', '')
data['Stars'] = pd.to_numeric(data['Stars'])

data
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country  \
# 0                             T's Restaurant Tantanmen    Cup     Japan
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan
# 2                         Cup Noodles Chicken Vegetable   Cup       USA
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan
# 4                                       Singapore Curry  Pack     India
# ...                                                 ...   ...       ...
# 2575  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl   Vietnam
# ...

# %%
# 2 Add a column to the DataFrame that stores the average rating for each country. 
# Then, display the first five rows and verify that the column was added and that its values appear to be correct.
data['Average Rating'] = data.groupby('Country')['Stars'].transform('mean')
data.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country  Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan   3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan   1.00
# 2                      Cup Noodles Chicken Vegetable   Cup     USA   2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan   2.75
# 4                                    Singapore Curry  Pack   India   3.75
#
#   Top Ten  Average Rating
# 0     NaN        3.981605
# 1     NaN        3.665402
# 2     NaN        3.457043
# 3     NaN        3.665402
# 4     NaN        3.395161

# %%
# 3 Group the data by the Country and Style columns and take the mean. 
# Then, unstack the Style column and display the data for the Stars column.
group = data.groupby(['Country', 'Style']).mean().reset_index()
group = group.set_index(['Country', 'Style'])['Stars'].unstack()
group
# Out:
# /tmp/ipykernel_2732/1780974292.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group = data.groupby(['Country', 'Style']).mean().reset_index()
# Style          Bar      Bowl   Box  Can       Cup      Pack      Tray
# Country
# Australia      NaN       NaN   NaN  NaN  3.120588  3.200000       NaN
# Bangladesh     NaN       NaN   NaN  NaN       NaN  3.714286       NaN
# Brazil         NaN       NaN   NaN  NaN  4.500000  4.250000       NaN
# Cambodia       NaN       NaN   NaN  NaN       NaN  4.200000       NaN
# Canada         NaN  2.281250   NaN  NaN  1.970588  2.515625       NaN
# China          NaN  3.527778   NaN  NaN  2.859375  3.538776  2.583333
# Colombia       NaN       NaN   NaN  NaN  3.083333  3.500000       NaN
# ...

# %%
# 4 Write a function that takes a row as input and returns a shortened version of the values in the Variety column. 
# The values should consist of the first two words of the variety name, followed by a space and an ellipsis
def short_variety(row):
    words = row['Variety'].split()
    return ' '.join(words[:2]) + ' ...'

# %%
# 5 Apply the function you just wrote to the DataFrame, and store the results in a column named ShortVariety. 
# Then, display the first five rows to be sure this worked
data['ShortVariety'] = data.apply(short_variety, axis=1)
data.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country  Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan   3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan   1.00
# 2                      Cup Noodles Chicken Vegetable   Cup     USA   2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan   2.75
# 4                                    Singapore Curry  Pack   India   3.75
#
#   Top Ten  Average Rating         ShortVariety
# 0     NaN        3.981605   T's Restaurant ...
# 1     NaN        3.665402    Noodles Spicy ...
# 2     NaN        3.457043      Cup Noodles ...
# 3     NaN        3.665402        GGE Ramen ...
# 4     NaN        3.395161  Singapore Curry ...

# %%
# 6 Set an index on the Brand column and then display the first five rows of data.
data = data.set_index('Brand')
data.head()
# Out:
#                 Review #                                            Variety  \
# Brand
# New Touch           2580                          T's Restaurant Tantanmen
# Just Way            2579  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# Nissin              2578                      Cup Noodles Chicken Vegetable
# Wei Lih             2577                      GGE Ramen Snack Tomato Flavor
# Ching's Secret      2576                                    Singapore Curry
#
#                Style Country  Stars Top Ten  Average Rating  \
# Brand
# New Touch        Cup   Japan   3.75     NaN        3.981605
# Just Way        Pack  Taiwan   1.00     NaN        3.665402
# Nissin           Cup     USA   2.25     NaN        3.457043
# Wei Lih         Pack  Taiwan   2.75     NaN        3.665402
# Ching's Secret  Pack   India   3.75     NaN        3.395161
#
#                        ShortVariety
# Brand
# New Touch        T's Restaurant ...
# Just Way          Noodles Spicy ...
# ...

# %%
# 7 Reset the index to its default
data.reset_index()
# Out:
#                Brand  Review #  \
# 0          New Touch      2580
# 1           Just Way      2579
# 2             Nissin      2578
# 3            Wei Lih      2577
# 4     Ching's Secret      2576
# ...              ...       ...
# 2575           Vifon         5
# 2576         Wai Wai         4
# 2577         Wai Wai         3
# 2578         Wai Wai         2
# 2579        Westbrae         1
#
#                                                 Variety Style   Country  \
# 0                             T's Restaurant Tantanmen    Cup     Japan
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan
# 2                         Cup Noodles Chicken Vegetable   Cup       USA
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan
# 4                                       Singapore Curry  Pack     India
# ...                                                 ...   ...       ...
# 2575  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl   Vietnam
# ...
