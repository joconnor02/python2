# %% [markdown]
# # Assignment.09 - Program 02

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Tasks

# %%
# 1 Read the data from the CSV file into a DataFrame and display the first five rows.
data = pd.read_csv("gold.csv")
data.head()
# Out:
#       Date  Price
# 0  1950-01  34.73
# 1  1950-02  34.73
# 2  1950-03  34.73
# 3  1950-04  34.73
# 4  1950-05  34.73

# %%
# 2 Run the info() method, and note the data types of the two columns.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    847 non-null    object
#  1   Price   847 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.4+ KB

# %%
# 3 Convert the Date column to the DateTime data type. 
# Then, display the first five rows of data, and note that the dates are for the first of each month starting in 1950.
data['Date'] = pd.to_datetime(data['Date'])
data.head()
# Out:
#         Date  Price
# 0 1950-01-01  34.73
# 1 1950-02-01  34.73
# 2 1950-03-01  34.73
# 3 1950-04-01  34.73
# 4 1950-05-01  34.73

# %%
# 4 Plot the data with a Pandas line plot.
data.plot(x='Date')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
# 5 Index the data on the Date column. Then, generate time periods for the first day of each year from 1950 to 2020.
data.set_index('Date', inplace=True)
time = pd.date_range(start='01/01/1950', end='01/01/2021', freq='Y')-pd.offsets.YearBegin(1)

# %%
# 6 Reindex the data using the new time periods, and display the first five rows again to see that there is just one row for each year.
data.reindex(time)
# Out:
#                Price
# 1950-01-01    34.730
# 1951-01-01    34.720
# 1952-01-01    34.490
# 1953-01-01    34.880
# 1954-01-01    34.860
# ...              ...
# 2016-01-01  1095.655
# 2017-01-01  1192.648
# 2018-01-01  1332.809
# 2019-01-01  1291.630
# 2020-01-01  1560.668
#
# [71 rows x 1 columns]

# %%
# 7 Plot the reindexed data with a Pandas line plot.
data.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
# 8 Resample the data to a quarterly frequency and plot the data again.
Qtime = pd.date_range(start='01/01/1950', end='01/01/2021', freq='QS')-pd.offsets.QuarterBegin(1)
data.reindex(Qtime) #This only works 30% of time time??
data.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
# 9 Resample the data to a yearly frequency and plot the data one more time
Ytime = pd.date_range(start='01/01/1950', end='01/01/2021', freq='Y')-pd.offsets.YearBegin(1)
data.reindex(Ytime) #This only works 30% of time time??
data.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
# 10 Plot the rolling mean for the data using a Pandas line plot. Experiment with different values for the window parameter
data.rolling(window=10).mean().plot()
# Out:
# <AxesSubplot: xlabel='Date'>
